# %%
using ITensors
using PyPlot
# Out:
# InitError: PyError (PyImport_ImportModule
#
# The Python package matplotlib could not be imported by pyimport. Usually this means
# that you did not install matplotlib in the Python version being used by PyCall.
#
# PyCall is currently configured to use the Python version at:
#
# /usr/bin/python3
#
# and you should use whatever mechanism you usually use (apt-get, pip, conda,
# etcetera) to install the Python package containing the matplotlib module.
#
# One alternative is to re-configure PyCall to use a different Python
# version on your system: set ENV["PYTHON"] to the path/name of the python
# executable you want to use, run Pkg.build("PyCall"), and re-launch Julia.
#
# Another alternative is to configure PyCall to use a Julia-specific Python
# distribution via the Conda.jl package (which installs a private Anaconda
# Python distribution), which has the advantage that packages can be installed
# and kept up-to-date via Julia.  As explained in the PyCall documentation,
# set ENV["PYTHON"]="", run Pkg.build("PyCall"), and re-launch Julia. Then,
# To install the matplotlib module, you can use `pyimport_conda("matplotlib", PKG)`,
# where PKG is the Anaconda package that contains the module matplotlib,
# or alternatively you can use the Conda package directly (via
# `using Conda` followed by `Conda.add` etcetera).
#
# ) <class 'ModuleNotFoundError'>
# ModuleNotFoundError("No module named 'matplotlib'")
#
# during initialization of module PyPlot
#
# Stacktrace:
#   [1] pyimport(name::String)
#     @ PyCall ~/.julia/packages/PyCall/ilqDX/src/PyCall.jl:558
#   [2] pyimport_conda(modulename::String, condapkg::String, channel::String)
#     @ PyCall ~/.julia/packages/PyCall/ilqDX/src/PyCall.jl:716
#   [3] pyimport_conda
#     @ ~/.julia/packages/PyCall/ilqDX/src/PyCall.jl:715 [inlined]
#   [4] __init__()
#     @ PyPlot ~/.julia/packages/PyPlot/2MlrT/src/init.jl:174
#   [5] register_restored_modules(sv::Core.SimpleVector, pkg::Base.PkgId, path::String)
#     @ Base ./loading.jl:1115
#   [6] _include_from_serialized(pkg::Base.PkgId, path::String, ocachepath::String, depmods::Vector{Any})
#     @ Base ./loading.jl:1061
#   [7] _require_search_from_serialized(pkg::Base.PkgId, sourcepath::String, build_id::UInt128)
#     @ Base ./loading.jl:1506
#   [8] _require(pkg::Base.PkgId, env::String)
#     @ Base ./loading.jl:1783
#   [9] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:1660
#  [10] macro expansion
#     @ ./loading.jl:1648 [inlined]
#  [11] macro expansion
#     @ ./lock.jl:267 [inlined]
#  [12] require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:1611

# %% [markdown]
# This notebook computes the groundstate of the XXZ-Hamiltonian at varying coupling strengths using ITensor.

# %% [markdown]
# # Define XXZ Hamiltonian

# %%
function H_XXZ(N, D, J)
    # create N spin-1 degrees of freedom 
    sites = siteinds("S=1", N)
    
    # init MPO 
    ampo = AutoMPO()
    
    for j = 1 : N - 1
        # usual Heisenberg term
        ampo += J, "Sx", j, "Sx", j + 1
        ampo += J, "Sy", j, "Sy", j + 1
        ampo += J, "Sz", j, "Sz", j + 1
        
        # biquadratic terms of each component
           
    end
    
    for j = 1 : N 
        
        # biquadratic terms of each component
        ampo += D, "Sz", j, "Sz", j    
    end
    
    
    # build final MPO 
    H = MPO(ampo, sites)
    
    return sites, H
end
# Out:
# H_XXZ (generic function with 1 method)

# %% [markdown]
# # Run DMRG calculation and return observer

# %%
function run_XXZ(N, D, J , sweeps)
    
    # build Hamiltonian
    sites, H = H_XXZ(N, D, J)
    
    # build random initial state 
    psi0 = randomMPS(sites, 1)
    
    # run DMRG calculation for ground state
    obs = DMRGObserver(energy_tol = 1E-8)
    E1, psi1 = dmrg(H, psi0, sweeps; observer = obs)

    return obs, E1, psi1
end
# Out:
# run_XXZ (generic function with 1 method)

# %% [markdown]
# # Set up system sizes and field strength

# %%
N = 10
J = 1
Ds = -1:0.05:2
# Out:
# -1.0:0.05:2.0

# %% [markdown]
# # Set up sweeps

# %%
N_sweeps = 50
sweeps   = Sweeps(N_sweeps)
maxdim!(sweeps, 80)
cutoff!(sweeps, 1e-5)

# %% [markdown]
# # set up buffers to store results

# %%
Ss = []
Es = []
# Out:
# Any[]

# %% [markdown]
# # Run DMRG calculation and obtain observer

# %%
for D in Ds
    # build Hamiltonian
    sites, H = H_XXZ(N, D, J)

    # build random initial state 
    psi0 = randomMPS(sites, 1)

    # build observer
    obs = DMRGObserver(energy_tol = 1E-8)

    # run DMRG calculation
    E, psi = dmrg(H, psi0, sweeps; observer = obs)

    # set bond for which we want to do the SVD 
    b = floor(Int64, N / 2)

    # gauge psi to bond b 
    orthogonalize!(psi, b)

    # perform SVD 
    U, S, V = svd(psi[b], (linkind(psi, b - 1), siteind(psi, b)))
    
    # compute s
    s = 0.0 

    for i in 1 : size(S, 1)
        s += -S[i, i]^2 * log(S[i, i]^2)
    end
    println(psi.llim)
    push!(Ss, s)
    push!(Es, E)
    
end
# Out:
# After sweep 1 energy=-21.04693253254665  maxlinkdim=8 maxerr=8.96E-06 time=15.453
# After sweep 2 energy=-21.05202160514746  maxlinkdim=7 maxerr=8.83E-06 time=0.012
# After sweep 3 energy=-21.052022190182043  maxlinkdim=7 maxerr=8.39E-06 time=0.026
# After sweep 4 energy=-21.05202218645066  maxlinkdim=7 maxerr=8.39E-06 time=0.011
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-20.593310315934716  maxlinkdim=7 maxerr=8.34E-06 time=0.008
# After sweep 2 energy=-20.60055720333278  maxlinkdim=7 maxerr=8.20E-06 time=0.010
# After sweep 3 energy=-20.600564046531794  maxlinkdim=7 maxerr=5.91E-06 time=0.030
# After sweep 4 energy=-20.600564079285  maxlinkdim=7 maxerr=5.91E-06 time=0.011
# After sweep 5 energy=-20.600564078984824  maxlinkdim=7 maxerr=5.91E-06 time=0.022
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-20.143710559379482  maxlinkdim=8 maxerr=8.12E-06 time=0.008
# After sweep 2 energy=-20.15145367075744  maxlinkdim=7 maxerr=8.60E-06 time=0.009
# After sweep 3 energy=-20.15146134373012  maxlinkdim=7 maxerr=7.10E-06 time=0.019
# After sweep 4 energy=-20.151461400138984  maxlinkdim=7 maxerr=7.10E-06 time=0.010
# After sweep 5 energy=-20.151461399728255  maxlinkdim=7 maxerr=7.10E-06 time=0.016
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=
-06 time=0.028
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-7.59997965133645  maxlinkdim=9 maxerr=9.55E-06 time=0.010
# After sweep 2 energy=-7.926190463535444  maxlinkdim=15 maxerr=9.83E-06 time=0.029
# After sweep 3 energy=-7.93324621164844  maxlinkdim=13 maxerr=9.19E-06 time=0.028
# After sweep 4 energy=-7.933235023282561  maxlinkdim=13 maxerr=9.19E-06 time=0.021
# After sweep 5 energy=-7.933235069817213  maxlinkdim=13 maxerr=9.02E-06 time=0.027
# After sweep 6 energy=-7.933235070075332  maxlinkdim=13 maxerr=9.02E-06 time=0.026
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-7.622563051732286  maxlinkdim=9 maxerr=9.25E-06 time=0.016
# After sweep 2 energy=-7.7333856303838875  maxlinkdim=15 maxerr=8.20E-06 time=0.021
# After sweep 3 energy=-7.734422309340144  maxlinkdim=13 maxerr=9.91E-06 time=0.051
# After sweep 4 energy=-7.734408863699708  maxlinkdim=12 maxerr=9.59E-06 time=0.033
# After sweep 5 energy=-7.734408876664631  maxlinkdim=12 maxerr=9.60E-06 time=0.027
# After sweep 6 energy=-7.734408876736454  maxlinkdim=12 maxerr=9.60E-06 time=0.028
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-7.293286772781043  maxlinkdim=9 maxerr=2.75E-07 time=0.010
# After sweep 2 energy=-7.540131649419243  maxlinkdim=15 maxerr=9.99E-06 time=0.028
# After sweep 3 energy=-7.541127100056711  maxlinkdim=12 maxerr=9.76E-06 time=0.026
# After sweep 4 energy=-7.541129083708402  maxlinkdim=12 maxerr=8.43E-06 time=0.022
# After sweep 5 energy=-7.5411290877030845  maxlinkdim=12 maxerr=8.43E-06 time=0.028
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-7.075723318596942  maxlinkdim=9 maxerr=9.44E-06 time=0.016
# After sweep 2 energy=-7.352456835068438  maxlinkdim=13 maxerr=9.78E-06 time=0.021
# After sweep 3 energy=-7.35331397345293  maxlinkdim=12 maxerr=9.88E-06 time=0.027
# After sweep 4 energy=-7.353315389320386  maxlinkdim=12 maxerr=7.38E-06 time=0.027
# After sweep 5 energy=-7.3533153919118925  maxlinkdim=12 maxerr=7.38E-06 time=0.031
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-6.9911624212287045  maxlinkdim=9 maxerr=9.88E-06 time=0.012
# After sweep 2 energy=-7.169791720190284  maxlinkdim=13 maxerr=8.60E-06 time=0.030
# After sweep 3 energy=-7.170899944256518  maxlinkdim=12 maxerr=8.41E-06 time=0.027
# After sweep 4 energy=-7.170901943338254  maxlinkdim=12 maxerr=6.46E-06 time=0.030
# After sweep 5 energy=-7.170901946441625  maxlinkdim=12 maxerr=6.45E-06 time=0.024
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-6.901598247895948  maxlinkdim=9 maxerr=9.30E-06 time=0.018
# After sweep 2 energy=-6.993710565016707  maxlinkdim=12 maxerr=8.14E-06 time=0.022
# After sweep 3 energy=-6.993818593088083  maxlinkdim=12 maxerr=6.25E-06 time=0.030
# After sweep 4 energy=-6.993818725108971  maxlinkdim=12 maxerr=5.62E-06 time=0.031
# After sweep 5 energy=-6.993818725465989  maxlinkdim=12 maxerr=5.62E-06 time=0.030
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-6.734036415390545  maxlinkdim=9 maxerr=8.82E-06 time=0.011
# After sweep 2 energy=-6.821814217620011  maxlinkdim=13 maxerr=9.99E-06 time=0.029
# After sweep 3 energy=-6.821894096287839  maxlinkdim=12 maxerr=9.86E-06 time=0.028
# After sweep 4 energy=-6.8218936488865705  maxlinkdim=12 maxerr=9.62E-06 time=0.021
# After sweep 5 energy=-6.821893502375006  maxlinkdim=12 maxerr=9.59E-06 time=0.027
# After sweep 6 energy=-6.821893458354268  maxlinkdim=12 maxerr=9.59E-06 time=0.029
# After sweep 7 energy=-6.821893446923571  maxlinkdim=12 maxerr=9.59E-06 time=0.027
# After sweep 8 energy=-6.821893444332453  maxlinkdim=12 maxerr=9.59E-06 time=0.027
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-6.361066067720731  maxlinkdim=9 maxerr=9.48E-06 time=0.010
# After sweep 2 energy=-6.654299188914558  maxlinkdim=13 maxerr=9.69E-06 time=0.027
# After sweep 3 energy=-6.655214859529271  maxlinkdim=12 maxerr=9.96E-06 time=0.022
# After sweep 4 energy=-6.655173907656955  maxlinkdim=12 maxerr=9.75E-06 time=0.028
# After sweep 5 energy=-6.655173583978147  maxlinkdim=12 maxerr=9.55E-06 time=0.027
# After sweep 6 energy=-6.655173414541255  maxlinkdim=12 maxerr=9.55E-06 time=0.030
# After sweep 7 energy=-6.655173345193786  maxlinkdim=12 maxerr=9.55E-06 time=0.023
# After sweep 8 energy=-6.655173319496492  maxlinkdim=12 maxerr=9.55E-06 time=0.026
# After sweep 9 energy=-6.655173310293028  maxlinkdim=12 maxerr=9.55E-06 time=0.028
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-6.344822765880036  maxlinkdim=9 maxerr=7.59E-06 time=0.010
# After sweep 2 energy=-6.493149881274843  maxlinkdim=12 maxerr=9.47E-06 time=0.026
# After sweep 3 energy=-6.493603950618487  maxlinkdim=11 maxerr=9.72E-06 time=0.027
# After sweep 4 energy=-6.493604274528583  maxlinkdim=11 maxerr=9.59E-06 time=0.019
# After sweep 5 energy=-6.493604681590198  maxlinkdim=11 maxerr=9.56E-06 time=0.029
# After sweep 6 energy=-6.493605171674972  maxlinkdim=11 maxerr=9.56E-06 time=0.027
# After sweep 7 energy=-6.493605329629049  maxlinkdim=11 maxerr=9.57E-06 time=0.023
# After sweep 8 energy=-6.4936053355350065  maxlinkdim=11 maxerr=9.57E-06 time=0.027
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-6.2004402501520905  maxlinkdim=9 maxerr=9.43E-06 time=0.018
# After sweep 2 energy=-6.336662122153614  maxlinkdim=12 maxerr=9.96E-06 time=0.020
# After sweep 3 energy=-6.337022689779613  maxlinkdim=11 maxerr=9.77E-06 time=0.025
# After sweep 4 energy=-6.337022757993834  maxlinkdim=11 maxerr=8.98E-06 time=0.025
# After sweep 5 energy=-6.337022624554978  maxlinkdim=11 maxerr=8.98E-06 time=0.019
# After sweep 6 energy=-6.337022545770018  maxlinkdim=11 maxerr=8.98E-06 time=0.026
# After sweep 7 energy=-6.3370225008483105  maxlinkdim=11 maxerr=8.98E-06 time=0.023
# After sweep 8 energy=-6.337022475014007  maxlinkdim=11 maxerr=8.98E-06 time=0.021
# After sweep 9 energy=-6.337022459858271  maxlinkdim=11 maxerr=8.98E-06 time=0.027
# After sweep 10 energy=-6.337022450763573  maxlinkdim=11 maxerr=8.98E-06 time=0.028
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-6.053594350449055  maxlinkdim=8 maxerr=9.39E-06 time=0.010
# After sweep 2 energy=-6.185165742587055  maxlinkdim=11 maxerr=9.30E-06 time=0.025
# After sweep 3 energy=-6.18535193905566  maxlinkdim=11 maxerr=9.08E-06 time=0.019
# After sweep 4 energy=-6.185352276558193  maxlinkdim=11 maxerr=9.07E-06 time=0.025
# After sweep 5 energy=-6.185352119019532  maxlinkdim=11 maxerr=9.07E-06 time=0.025
# After sweep 6 energy=-6.185351985314992  maxlinkdim=11 maxerr=9.07E-06 time=0.019
# After sweep 7 energy=-6.185351901170739  maxlinkdim=11 maxerr=9.07E-06 time=0.025
# After sweep 8 energy=-6.185351856576931  maxlinkdim=11 maxerr=9.07E-06 time=0.027
# After sweep 9 energy=-6.185351835049734  maxlinkdim=11 maxerr=9.07E-06 time=0.019
# After sweep 10 energy=-6.185351825121349  maxlinkdim=11 maxerr=9.07E-06 time=0.027
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-5.89880858523817  maxlinkdim=9 maxerr=1.19E-06 time=0.010
# After sweep 2 energy=-6.038459842110559  maxlinkdim=11 maxerr=8.76E-06 time=0.024
# After sweep 3 energy=-6.038472435303892  maxlinkdim=10 maxerr=9.85E-06 time=0.022
# After sweep 4 energy=-6.038472468036063  maxlinkdim=10 maxerr=9.26E-06 time=0.018
# After sweep 5 energy=-6.038472468190062  maxlinkdim=10 maxerr=9.26E-06 time=0.023
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-5.264159527548105  maxlinkdim=9 maxerr=5.72E-06 time=0.009
# After sweep 2 energy=-5.896038306224538  maxlinkdim=11 maxerr=9.97E-06 time=0.024
# After sweep 3 energy=-5.89630130389885  maxlinkdim=10 maxerr=9.89E-06 time=0.022
# After sweep 4 energy=-5.896301699732257  maxlinkdim=10 maxerr=9.57E-06 time=0.017
# After sweep 5 energy=-5.89630170128729  maxlinkdim=10 maxerr=9.57E-06 time=0.024
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-5.327988042628805  maxlinkdim=9 maxerr=4.46E-06 time=0.009
# After sweep 2 energy=-5.758549523917611  maxlinkdim=10 maxerr=8.86E-06 time=0.023
# After sweep 3 energy=-5.758722629460719  maxlinkdim=9 maxerr=9.01E-06 time=0.023
# After sweep 4 energy=-5.7587230224883  maxlinkdim=9 maxerr=8.88E-06 time=0.017
# After sweep 5 energy=-5.758723024277543  maxlinkdim=9 maxerr=8.88E-06 time=0.023
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-5.613681485471387  maxlinkdim=9 maxerr=8.99E-06 time=0.010
# After sweep 2 energy=-5.625615527722548  maxlinkdim=9 maxerr=8.59E-06 time=0.022
# After sweep 3 energy=-5.625617451129685  maxlinkdim=9 maxerr=7.35E-06 time=0.016
# After sweep 4 energy=-5.625617451511115  maxlinkdim=9 maxerr=7.34E-06 time=0.023
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-5.286179565926539  maxlinkdim=9 maxerr=6.61E-06 time=0.009
# After sweep 2 energy=-5.496767394022428  maxlinkdim=10 maxerr=9.99E-06 time=0.022
# After sweep 3 energy=-5.496851600806013  maxlinkdim=9 maxerr=6.77E-06 time=0.016
# After sweep 4 energy=-5.496851613881796  maxlinkdim=9 maxerr=6.07E-06 time=0.022
# After sweep 5 energy=-5.4968516139064345  maxlinkdim=9 maxerr=6.07E-06 time=0.022
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-5.355286988037763  maxlinkdim=9 maxerr=5.08E-06 time=0.009
# After sweep 2 energy=-5.372304975542127  maxlinkdim=9 maxerr=8.38E-06 time=0.024
# After sweep 3 energy=-5.372305519582505  maxlinkdim=9 maxerr=5.03E-06 time=0.018
# After sweep 4 energy=-5.372305518440881  maxlinkdim=9 maxerr=5.03E-06 time=0.022
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-4.438672226538123  maxlinkdim=9 maxerr=6.85E-06 time=0.011
# After sweep 2 energy=-5.186940880306179  maxlinkdim=13 maxerr=9.71E-06 time=0.023
# After sweep 3 energy=-5.251845702686641  maxlinkdim=9 maxerr=8.51E-06 time=0.017
# After sweep 4 energy=-5.251857287407389  maxlinkdim=9 maxerr=4.28E-06 time=0.022
# After sweep 5 energy=-5.251857288629887  maxlinkdim=9 maxerr=4.16E-06 time=0.022
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-5.070912348050682  maxlinkdim=9 maxerr=6.21E-06 time=0.010
# After sweep 2 energy=-5.135339535431368  maxlinkdim=9 maxerr=7.25E-06 time=0.021
# After sweep 3 energy=-5.1353838471253335  maxlinkdim=9 maxerr=3.72E-06 time=0.016
# After sweep 4 energy=-5.135383848979359  maxlinkdim=9 maxerr=3.45E-06 time=0.022
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-4.942047929112772  maxlinkdim=9 maxerr=9.32E-06 time=0.014
# After sweep 2 energy=-5.02275293772695  maxlinkdim=9 maxerr=7.14E-06 time=0.028
# After sweep 3 energy=-5.02276157786292  maxlinkdim=9 maxerr=2.95E-06 time=0.022
# After sweep 4 energy=-5.022761575642175  maxlinkdim=9 maxerr=2.86E-06 time=0.029
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-4.843058016224643  maxlinkdim=9 maxerr=8.35E-06 time=0.014
# After sweep 2 energy=-4.913857055976593  maxlinkdim=9 maxerr=3.90E-06 time=0.029
# After sweep 3 energy=-4.913866904103181  maxlinkdim=9 maxerr=2.46E-06 time=0.022
# After sweep 4 energy=-4.913866903003186  maxlinkdim=9 maxerr=2.38E-06 time=0.029
# Energy difference less than 1.0e-8, stopping DMRG
# 4
# After sweep 1 energy=-4.291106845673677  maxlinkdim=9 maxerr=8.84E-06 time=0.014
# After sweep 2 energy=-4.8085197163736675  maxlinkdim=9 maxerr=7.98E-06 time=0.029
# After sweep 3 energy=-4.808576879370424  maxlinkdim=9 maxerr=2.24E-06 time=0.021
# After sweep 4 energy=-4.808576878761373  maxlinkdim=9 maxerr=1.97E-06 time=0.026
# Energy difference less than 1.0e-8, stopping DMRG
# 4

# %% [markdown]
# # Plot result

# %%
fig = figure(figsize = (9, 6))

xlabel("D")
ylabel("entanglement entropy")

plot(Ds, Ss, marker = "o", markersize = 8.0, color = "blue")

tight_layout()

# fit = curve_fit(model, log.(Ns), Ss, [0.5, 0.5])
# c   = 6.0 * coef(fit)[1]

# println("Central charge is $(c).")
show()

# %%
# plot data 
# pygui(true)
fig = figure(figsize = (9, 6))

xlabel("D")
ylabel("Gs energy")

plot(Ds, Es, marker = "o", markersize = 8.0, color = "blue")

tight_layout()

# fit = curve_fit(model, log.(Ns), Ss, [0.5, 0.5])
# c   = 6.0 * coef(fit)[1]

# println("Central charge is $(c).")
show()
